# %% [markdown]
# # Pyspark

# %%
'''#!pip install pyspark
#!pip install findspark
#!pip install setuptools
import pyspark
import findspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
import setuptools
from pyspark.sql.types import DoubleType
from pyspark.sql.window import Window
findspark.init()
spark=SparkSession.builder.getOrCreate()
spark'''
# Out:
# '#!pip install pyspark\n#!pip install findspark\n#!pip install setuptools\nimport pyspark\nimport findspark\nfrom pyspark.sql import SparkSession\nfrom pyspark.sql.functions import *\nimport setuptools\nfrom pyspark.sql.types import DoubleType\nfrom pyspark.sql.window import Window\nfindspark.init()\nspark=SparkSession.builder.getOrCreate()\nspark'

# %%
#spark.stop()

# %% [markdown]
# ## Base Contratos Carnê

# %%
'''# Lendo o arquivo CSV
# Base Contratos Carne

arquivos = [
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-03-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-04-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-05-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-06-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-07-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-08-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-09-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-10-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-11-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-12-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-01-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-02-28.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-03-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-04-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-05-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-06-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-07-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-08-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-09-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-10-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-11-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-12-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-01-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-02-29.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-03-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-04-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-05-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-06-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-07-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-08-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-09-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-10-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-11-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2024-12-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2025-01-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2025-02-28.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2025-03-31.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2025-04-30.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/Behavior_20250518_1.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/Behavior_20250518_2.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/Behavior_20250518_3.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/Behavior_20250518_4.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/Behavior_20250518_5.csv",
    "C:/Users/fernando.monteiro/Downloads/carne/Behavior_20250518_6.csv"]
df = spark.read.csv(arquivos,sep=";", header=True, inferSchema=True)'''
# Out:
# '# Lendo o arquivo CSV\n# Base Contratos Carne\n\narquivos = [\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-03-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-04-30.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-05-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-06-30.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-07-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-08-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-09-30.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-10-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-11-30.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2022-12-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/carne/dados_behavior_2023-01-31.csv",\n    "C:/Users/fernando.monteiro/Downloads/c
# ...

# %%
'''# Função para trocar , por . em colunas numéricas
def formatar_col_num(df, colunas):
    for nome_coluna in colunas:
        df = df.withColumn(
            nome_coluna,
            regexp_replace(col(nome_coluna), r"\.", "")  
        )
        df = df.withColumn(
            nome_coluna,
            regexp_replace(col(nome_coluna), ",", ".").cast(DoubleType())
        )
    return df'''
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\fernando.monteiro\AppData\Local\Temp\ipykernel_10588\1033524141.py:1: SyntaxWarning: invalid escape sequence '\.'
#   '''# Função para trocar , por . em colunas numéricas
# '# Função para trocar , por . em colunas numéricas\ndef formatar_col_num(df, colunas):\n    for nome_coluna in colunas:\n        df = df.withColumn(\n            nome_coluna,\n            regexp_replace(col(nome_coluna), r"\\.", "")  \n        )\n        df = df.withColumn(\n            nome_coluna,\n            regexp_replace(col(nome_coluna), ",", ".").cast(DoubleType())\n        )\n    return df'

# %%
'''# colunas numéricas
col_num=[
    "cpf_cnpj",
    "id_contrato"
    ]

df = formatar_col_num(df, col_num)'''
# Out:
# '# colunas numéricas\ncol_num=[\n    "cpf_cnpj",\n    "id_contrato"\n    ]\n\ndf = formatar_col_num(df, col_num)'

# %%
'''#df = df.withColumn("anomes_new",
#                   to_date(concat_ws("-", df["anomes"], lit("01")), "yyyy-MM-dd"))
df = df.withColumn(
    "anomes_new",
    to_date(expr("concat(substr(anomes, 1, 4), '-', substr(anomes, 6, 2), '-01')"), "yyyy-MM-dd")
)'''
# Out:
# '#df = df.withColumn("anomes_new",\n#                   to_date(concat_ws("-", df["anomes"], lit("01")), "yyyy-MM-dd"))\ndf = df.withColumn(\n    "anomes_new",\n    to_date(expr("concat(substr(anomes, 1, 4), \'-\', substr(anomes, 6, 2), \'-01\')"), "yyyy-MM-dd")\n)'

# %%
'''window_spec = Window.partitionBy("cpf_cnpj", "id_contrato").orderBy(desc("anomes_new"))

df_com_ranking = df.withColumn("registro", row_number().over(window_spec))

df_ultima_movimentacao = df_com_ranking.filter("registro = 1").drop("registro")'''
# Out:
# 'window_spec = Window.partitionBy("cpf_cnpj", "id_contrato").orderBy(desc("anomes_new"))\n\ndf_com_ranking = df.withColumn("registro", row_number().over(window_spec))\n\ndf_ultima_movimentacao = df_com_ranking.filter("registro = 1").drop("registro")'

# %%
#df_ultima_movimentacao.printSchema()

# %%
#df_ultima_movimentacao.show(5)

# %%
#df_ultima_movimentacao.count()

# %%
'''caminho_saida = "C:/Users/fernando.monteiro/Downloads/output_final"

df_ultima_movimentacao.coalesce(1).write.format("csv").mode("overwrite").option("header", True).save(caminho_saida)'''
# Out:
# 'caminho_saida = "C:/Users/fernando.monteiro/Downloads/output_final"\n\ndf_ultima_movimentacao.coalesce(1).write.format("csv").mode("overwrite").option("header", True).save(caminho_saida)'

# %%
#df.filter(col("id_contrato")==140988050).show()

# %%
# Filtro
#df_ultima_movimentacao.filter(col("id_contrato")==140988050).show()

# %%
#df.show()

# %%
#df.groupBy("anomes_new").count().show(100)

# %% [markdown]
# # Polars

# %%
#%pip install polars

import polars as pl
import numpy as np
from pathlib import Path
import glob
from datetime import datetime

# %%
hoje = datetime.today().strftime("%Y%m")

# %% [markdown]
# ## Base contratos Carnê

# %%
# Caminho dos arquivos
arquivos = glob.glob("C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Base Contratos Carne/carne/*.csv")

# Colunas para somar
cols_a_vencer = [
    "creditos_a_vencer_ate_30_dias",
    "creditos_a_vencer_de_31_e_60_dias",
    "creditos_a_vencer_de_61_e_90_dias",
    "creditos_a_vencer_de_91_e_180_dias",
    "creditos_a_vencer_de_181_e_360_dias",
    "creditos_a_vencer_de_361_e_720_dias",
    "creditos_a_vencer_de_721_e_1080_dias",
    "creditos_a_vencer_de_1081_e_1440_dias",
    "creditos_a_vencer_de_1441_e_1800_dias",
    "creditos_a_vencer_de_1801_e_5400_dias",
    "creditos_a_vencer_acima_de_5400_dias"
]

cols_vencidos = [
    "creditos_vencidos_de_1_a_14_dias",
    "creditos_vencidos_de_15_a_30_dias",
    "creditos_vencidos_de_31_a_60_dias",
    "creditos_vencidos_de_61_a_90_dias",
    "creditos_vencidos_de_91_a_120_dias",
    "creditos_vencidos_de_121_a_150_dias",
    "creditos_vencidos_de_151_a_180_dias",
    "creditos_vencidos_de_181_a_240_dias",
    "creditos_vencidos_de_241_a_300_dias",
    "creditos_vencidos_de_301_a_360_dias",
    "creditos_vencidos_de_361_a_540_dias",
    "creditos_vencidos_acima_de_540_dias"
]

dfs = []

for f in arquivos:
    try:
        print(f"\n Lendo arquivo: {f}")
        # Leitura dos arquivos
        esquema = {
            "anomes": pl.Utf8, 
            "cpf_cnpj": pl.Float64, 
            "conceito": pl.Utf8,
            "id_contrato": pl.Float64,
            "id_financeira": pl.Utf8,
            "data": pl.Date,
            "id_agente": pl.Utf8,
            "dias_carencia": pl.Int32,
            "taxajuros": pl.Float32,
            "cet": pl.Float32,
            "saldo_contabil": pl.Float32,
            "dias_maior_atraso": pl.Int32,
            "dias_maior_atraso_aberto": pl.Int32,
            "media_atraso": pl.Float32,
            "qtd_parcelas": pl.Int32,
            "qtd_parcelas_abertas": pl.Int32,
            "qtd_parcelas_pagas": pl.Int32,
            "valor_entrada": pl.Float32,
            "valor_pago": pl.Float32,
            "valor_pago_atraso": pl.Float32,
            "valor_parcela": pl.Float32,
            "data_vencimento_prox_parcela": pl.Date,
            "data_vencimento_ultima_parcela": pl.Date,
            "principal_total": pl.Float32,
            "servicos_financeiros": pl.Float32,
            "flag_renegociacao": pl.Utf8,
            **{col: pl.Float32 for col in cols_a_vencer + cols_vencidos}
           }
        df = pl.read_csv(
            f,
            separator=";",
            null_values=["null"],
            ignore_errors=True,
            schema_overrides=esquema,
            decimal_comma=True
            )
        
        # Criar colunas de soma logo após leitura
        df = df.with_columns([
            pl.sum_horizontal(pl.col(cols_a_vencer)).alias("creditos_a_vencer"),
            pl.sum_horizontal(pl.col(cols_vencidos)).alias("creditos_vencidos")
        ])
        df = df.drop(cols_a_vencer + cols_vencidos)
        dfs.append(df) # Salva dataframe
        # Mostra resumo e cabeçalho
        print(f"Número de colunas: {len(df.columns)}")
        print("Nome e tipo das colunas:")
        for nome, tipo in zip(df.columns, df.dtypes):
            print(f" - {nome}: {tipo}")

        print("\n Primeiras linhas:")
        print(df.head(3))


    except Exception as e:
        print(f"Erro ao ler {f}: {e}")
        
# Concatenar tudo ao final
if dfs:
    df_concatenado = pl.concat(dfs, how="vertical_relaxed")
    print("\n Arquivos concatenados com sucesso.")
else:
    print("Nenhum arquivo pôde ser lido com sucesso.")
# Out:
#  Lendo arquivo: C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Base Contratos Carne/carne\Behavior_20250518_2.csv
# Número de colunas: 28
# Nome e tipo das colunas:
#  - anomes: String
#  - cpf_cnpj: Float64
#  - conceito: String
#  - id_contrato: Float64
#  - id_financeira: String
#  - data: Date
#  - id_agente: String
#  - dias_carencia: Int32
#  - taxajuros: Float32
#  - cet: Float32
#  - saldo_contabil: Float32
#  - dias_maior_atraso: Int32
#  - dias_maior_atraso_aberto: Int32
#  - media_atraso: Float32
#  - qtd_parcelas: Int32
#  - qtd_parcelas_abertas: Int32
#  - qtd_parcelas_pagas: Int32
#  - valor_entrada: Float32
#  - valor_pago: Float32
#  - valor_pago_atraso: Float32
#  - valor_parcela: Float32
#  - data_vencimento_prox_parcela: Date
#  - data_vencimento_ultima_parcela: Date
#  - principal_total: Float32
#  - servicos_financeiros: Float32
#  - flag_renegociacao: String
#  - creditos_a_vencer: Float32
#  - creditos_vencidos: Float32
#
#  Primeiras linhas:
# ...

# %%
df_concatenado=df_concatenado.filter(pl.col("data")>= pl.lit("2022-03-01").cast(pl.Date)) # filtro

# %%
#df_concatenado.head(3)

# %%
#df_concatenado.shape

# %%
'''df_counts = df_concatenado.group_by("data").agg(
    pl.count().alias("frequencia")
).sort("data", descending=True)'''
# Out:
# 'df_counts = df_concatenado.group_by("data").agg(\n    pl.count().alias("frequencia")\n).sort("data", descending=True)'

# %%
#df_counts

# %%
# Conversão das variáveis categoricas
df_concatenado = df_concatenado.with_columns([
    pl.col("id_agente").str.strip_chars().cast(pl.Categorical).alias("id_agente")
])

# %%
#df_concatenado.head(5)

# %%
#df_concatenado.filter(pl.col("id_contrato").is_null()) # filtro

# %%
# Conversão da coluna "anomes" para data
df_concatenado = df_concatenado.with_columns([
    (pl.col("anomes")
    .str.slice(0, 4) + "-" + pl.col("anomes").str.slice(5, 2) + "-01")
    .str.strptime(pl.Date, "%Y-%m-%d")
    .alias("anomes_new")
])
#df_concatenado.select(pl.col("anomes_new").unique())

# %%
df_ultima_movimentacao = (
    df_concatenado
    .group_by(["cpf_cnpj", "id_contrato"])
    .agg(
        pl.col("*").gather(pl.col("anomes_new").arg_max())
    )
    .explode([col for col in df_concatenado.columns if col not in ["cpf_cnpj", "id_contrato"]])
)

# %%
#df_ultima_movimentacao.shape

# %%
# Exibição
print(df_ultima_movimentacao.head())
print(df_ultima_movimentacao.shape)
# Out:
# shape: (5, 29)
# ┌───────────┬────────────┬─────────┬──────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ cpf_cnpj  ┆ id_contrat ┆ anomes  ┆ conceito ┆ … ┆ flag_reneg ┆ creditos_ ┆ creditos_ ┆ anomes_ne │
# │ ---       ┆ o          ┆ ---     ┆ ---      ┆   ┆ ociacao    ┆ a_vencer  ┆ vencidos  ┆ w         │
# │ f64       ┆ ---        ┆ str     ┆ str      ┆   ┆ ---        ┆ ---       ┆ ---       ┆ ---       │
# │           ┆ f64        ┆         ┆          ┆   ┆ str        ┆ f32       ┆ f32       ┆ date      │
# ╞═══════════╪════════════╪═════════╪══════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 4.0172e9  ┆ 1.2078e10  ┆ 2025/08 ┆ 4        ┆ … ┆ NAO        ┆ 0.0       ┆ 2323.6000 ┆ 2025-08-0 │
# │           ┆            ┆         ┆          ┆   ┆            ┆           ┆ 98        ┆ 1         │
# │ 9.6854e9  ┆ 1.0956e10  ┆ 2025/08 ┆ 4        ┆ … ┆ NAO        ┆ 0.0       ┆ 0.0       ┆ 2025-08-0 │
# ...

# %% [markdown]
# ### ULT PAG

# %%
dt_pg = pl.read_parquet("C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Ultimo pagamento/DT_PG/data_pag.parquet")

# %%
dt_pg_nulos = pl.read_parquet("C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Ultimo pagamento/DT_PG/data_pag_nulos.parquet")

# %%
# mês 08
dt_pg_08 = pl.read_csv("C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Ultimo pagamento/DT_PG/08.2025.csv",separator=";")
dt_pg_08 = dt_pg_08.rename({
    "00:00:00": "ParcelaDataPagto"
})

# %%
dt_pg=dt_pg.select(["CPF","Contrato","ParcelaDataPagto","ParcelaNumero"])
dt_pg_nulos=dt_pg_nulos.select(["CPF","Contrato","ParcelaDataPagto","ParcelaNumero"])
dt_pg_08=dt_pg_08.select(["CPF","Contrato","ParcelaDataPagto","ParcelaNumero"])# mês 08

dt_pg_concatenado=pl.concat([dt_pg,dt_pg_nulos,dt_pg_08], how="vertical_relaxed")

# %%
#dt_pg_nulos

# %%
# variável id cpf contrato e n° da parcela
dt_pg_concatenado = dt_pg_concatenado.with_columns([
    (pl.col("CPF").cast(pl.Float64).cast(pl.Utf8) + "-" + 
     pl.col("Contrato").cast(pl.Float64).cast(pl.Utf8) + "-" + 
     pl.col("ParcelaNumero").cast(pl.Int32).cast(pl.Utf8))
    .alias("cpf_contrato_nparc")
])

# %%
#dt_pg_concatenado

# %%
df_ultima_movimentacao = df_ultima_movimentacao.with_columns([
    (pl.col("cpf_cnpj").cast(pl.Utf8) + "-" + 
     pl.col("id_contrato").cast(pl.Utf8) + "-" + 
     pl.col("qtd_parcelas_pagas").cast(pl.Utf8))
    .alias("cpf_contrato_nparc")
])

# %%
#df_ultima_movimentacao

# %%
df_ultima_movimentacao_dt_pag = df_ultima_movimentacao.join(dt_pg_concatenado, on="cpf_contrato_nparc", how="left")

# %%
# Salvar em CSV
#df_ultima_movimentacao_dt_pag.write_csv(f"saida_carne_{hoje}.csv",separator=";",include_header=True)
df_ultima_movimentacao_dt_pag.write_parquet(f"saida_carne_{hoje}.parquet")

# %% [markdown]
# ## Base contratos Cartão

# %%
# Caminho dos arquivos
arquivos = glob.glob("C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Base Contratos cartão/cartao/*.csv")

# Colunas para somar
cols_a_vencer = [
    "CREDITOS_A_VENCER_ATE_30_DIAS",
    "CREDITOS_A_VENCER_DE_31_A_60_DIAS",
    "CREDITOS_A_VENCER_DE_61_A_90_DIAS",
    "CREDITOS_A_VENCER_DE_91_A_180_DIAS",
    "CREDITOS_A_VENCER_DE_181_A_360_DIAS",
    "CREDITOS_A_VENCER_DE_361_A_720_DIAS",
    "CREDITOS_A_VENCER_DE_721_A_1080_DIAS",
    "CREDITOS_A_VENCER_DE_1081_A_1440_DIAS",
    "CREDITOS_A_VENCER_DE_1441_A_1800_DIAS",
    "CREDITOS_A_VENCER_DE_1801_A_5400_DIAS",
    "CREDITOS_A_VENCER_ACIMA_DE_5400_DIAS",
]

cols_vencidos = [
    "CREDITOS_VENCIDOS_DE_1_A_14_DIAS",
    "CREDITOS_VENCIDOS_DE_15_A_30_DIAS",
    "CREDITOS_VENCIDOS_DE_31_A_60_DIAS",
    "CREDITOS_VENCIDOS_DE_61_A_90_DIAS",
    "CREDITOS_VENCIDOS_DE_91_A_120_DIAS",
    "CREDITOS_VENCIDOS_DE_121_A_150_DIAS",
    "CREDITOS_VENCIDOS_DE_151_A_180_DIAS",
    "CREDITOS_VENCIDOS_DE_181_A_240_DIAS",
    "CREDITOS_VENCIDOS_DE_241_A_300_DIAS",
    "CREDITOS_VENCIDOS_DE_301_A_360_DIAS",
    "CREDITOS_VENCIDOS_DE_361_A_540_DIAS",
    "CREDITOS_VENCIDOS_ACIMA_DE_540_DIAS"
]

dfs = []

for f in arquivos:
    try:
        print(f"\n Lendo arquivo: {f}")
        # Leitura dos arquivos
        esquema = {
            "ANO_MES_MOVIMENTO": pl.Utf8, 
            "DATA_MOVIMENTO": pl.Date, 
            "CPF_CNPJ": pl.Utf8, 
            "NUMERO_CONTRATO": pl.Float64,
            "DATA_CONTRATO": pl.Date,
            "MODALIDADE": pl.Int32,
            "TIPO_ACORDO": pl.Utf8,
            "DIAS_CARENCIA": pl.Int32,
            "TAXA_JUROS": pl.Float32,
            "CET": pl.Float32,
            "SALDO_CONTABIL": pl.Float32,
            "DIAS_MAIOR_ATRASO": pl.Int32,
            "DIAS_MAIOR_ATRASO_ABERTO": pl.Int32,
            "MEDIA_ATRASO": pl.Float32,
            "QTD_PARCELAS": pl.Int32,
            "QTD_PARCELAS_ABERTAS": pl.Int32,
            "QTD_PARCELAS_PAGAS": pl.Int32,
            "VALOR_PAGO": pl.Float32,
            "DATA_ULTIMO_PAGAMENTO": pl.Date,
            "JUROS_PAGOS_ATRASO": pl.Float32,
            "VALOR_PARCELA": pl.Float32,
            "DATA_VENCIMENTO_PROX_PARCELA": pl.Date,
            "DATA_VENCIMENTO_ULTIMA_PARCELA": pl.Date,
            "VALOR_CALCULADO": pl.Float32,
            "VALOR_DESCONTO": pl.Float32,
            "PRINCIPAL_TOTAL": pl.Float32,
            "VALOR_FINANCIADO": pl.Float32,
            "TIPO_OPERACAO": pl.Utf8,
            "FLAG_RENEGOCIACAO": pl.Utf8,
            **{col: pl.Float32 for col in cols_a_vencer + cols_vencidos}
           }
        df = pl.read_csv(
            f,
            separator=";",
            null_values=["null"],
            ignore_errors=True,
            schema_overrides=esquema,
            decimal_comma=True
            )
        
        # Criar colunas de soma logo após leitura
        df = df.with_columns([
            pl.sum_horizontal(pl.col(cols_a_vencer)).alias("creditos_a_vencer"),
            pl.sum_horizontal(pl.col(cols_vencidos)).alias("creditos_vencidos")
        ])
        df = df.drop(cols_a_vencer + cols_vencidos)
        df = df.with_columns(
            pl.col("CPF_CNPJ").str.strip_chars().cast(pl.Float64)
            )

        dfs.append(df) # Salva dataframe
        # Mostra resumo e cabeçalho
        print(f"Número de colunas: {len(df.columns)}")
        print("Nome e tipo das colunas:")
        for nome, tipo in zip(df.columns, df.dtypes):
            print(f" - {nome}: {tipo}")

        print("\n Primeiras linhas:")
        print(df.head(3))


    except Exception as e:
        print(f"Erro ao ler {f}: {e}")
        
# Concatenar tudo ao final
if dfs:
    df2_concatenado = pl.concat(dfs, how="vertical_relaxed")
    print("\n Arquivos concatenados com sucesso.")
else:
    print("Nenhum arquivo pôde ser lido com sucesso.")
# Out:
#  Lendo arquivo: C:/Users/fernando.monteiro/OneDrive - BHS/KAB/Base Behavior/Base Contratos cartão/cartao\BASEBEHAVIORCONTRATOS_2025-08-31.csv
# Número de colunas: 32
# Nome e tipo das colunas:
#  - ANO_MES_MOVIMENTO: String
#  - DATA_MOVIMENTO: Date
#  - CPF_CNPJ: Float64
#  - NUMERO_CONTRATO: Float64
#  - DATA_CONTRATO: Date
#  - MODALIDADE: Int32
#  - TIPO_ACORDO: String
#  - DIAS_CARENCIA: Int32
#  - TAXA_JUROS: Float32
#  - CET: Float32
#  - SALDO_CONTABIL: Float32
#  - DIAS_MAIOR_ATRASO_ABERTO: Int32
#  - DIAS_MAIOR_ATRASO: Int32
#  - MEDIA_ATRASO: Float32
#  - QTD_PARCELAS: Int32
#  - QTD_PARCELAS_ABERTAS: Int32
#  - QTD_PARCELAS_PAGAS: Int32
#  - VALOR_PAGO: Float32
#  - DATA_ULTIMO_PAGAMENTO: Date
#  - JUROS_PAGOS_ATRASO: Float32
#  - VALOR_PARCELA: Float32
#  - DATA_VENCIMENTO_PROX_PARCELA: Date
#  - DATA_VENCIMENTO_ULTIMA_PARCELA: Date
#  - VALOR_CALCULADO: Float32
#  - VALOR_DESCONTO: Float32
#  - PRINCIPAL_TOTAL: Float32
#  - VALOR_FINANCIADO: Float32
# ...

# %%
df2_concatenado=df2_concatenado.filter(pl.col("DATA_CONTRATO")>= pl.lit("2022-03-01").cast(pl.Date)) # filtro

# %%
maior_data = df2_concatenado["DATA_MOVIMENTO"].max()
print(maior_data)
# Out:
# 2025-08-31

# %%
df2_concatenado=df2_concatenado.filter(pl.col("DATA_CONTRATO")<= pl.lit(maior_data).cast(pl.Date)) # filtro

# %%
df2_concatenado.filter(pl.col("NUMERO_CONTRATO")== pl.lit(3045971)) # filtro
# Out:
# shape: (9, 32)
# ┌────────────┬────────────┬───────────┬────────────┬───┬────────────┬──────┬───────────┬───────────┐
# │ ANO_MES_MO ┆ DATA_MOVIM ┆ CPF_CNPJ  ┆ NUMERO_CON ┆ … ┆ FLAG_RENEG ┆      ┆ creditos_ ┆ creditos_ │
# │ VIMENTO    ┆ ENTO       ┆ ---       ┆ TRATO      ┆   ┆ OCIACAO    ┆ ---  ┆ a_vencer  ┆ vencidos  │
# │ ---        ┆ ---        ┆ f64       ┆ ---        ┆   ┆ ---        ┆ str  ┆ ---       ┆ ---       │
# │ str        ┆ date       ┆           ┆ f64        ┆   ┆ str        ┆      ┆ f32       ┆ f32       │
# ╞════════════╪════════════╪═══════════╪════════════╪═══╪════════════╪══════╪═══════════╪═══════════╡
# │ 2025-08    ┆ 2025-08-31 ┆ 5.1458e10 ┆ 3.045971e6 ┆ … ┆ NAO        ┆ null ┆ 0.0       ┆ 0.0       │
# │ 2025-07    ┆ 2025-07-31 ┆ 5.1458e10 ┆ 3.045971e6 ┆ … ┆ NAO        ┆ null ┆ 0.0       ┆ 0.0       │
# │ 2025-07    ┆ 2025-07-31 ┆ 5.1458e10 ┆ 3.045971e6 ┆ … ┆ NAO        ┆ null ┆ 0.0       ┆ 0.0       │
# ...

# %%
'''df2_counts = df2_concatenado.group_by("DATA_CONTRATO").agg(
    pl.count().alias("frequencia")
).sort("DATA_CONTRATO", descending=True)'''
# Out:
# 'df2_counts = df2_concatenado.group_by("DATA_CONTRATO").agg(\n    pl.count().alias("frequencia")\n).sort("DATA_CONTRATO", descending=True)'

# %%
#df2_counts

# %%
#df2_concatenado.head(3)

# %%
#df2_concatenado.shape

# %%
'''df2_counts = df2_concatenado.group_by("DATA_CONTRATO").agg(
    pl.count().alias("frequencia")
).sort("DATA_CONTRATO", descending=True)'''
# Out:
# 'df2_counts = df2_concatenado.group_by("DATA_CONTRATO").agg(\n    pl.count().alias("frequencia")\n).sort("DATA_CONTRATO", descending=True)'

# %%
#df2_counts

# %%
df2_ultima_movimentacao = (
    df2_concatenado
    .group_by(["CPF_CNPJ", "NUMERO_CONTRATO"])
    .agg(
        pl.col("*").gather(pl.col("DATA_MOVIMENTO").arg_max())
    )
    .explode([col for col in df2_concatenado.columns if col not in ["CPF_CNPJ", "NUMERO_CONTRATO"]])
)

# %%
#df2_ultima_movimentacao.shape

# %%
# Exibição
print(df2_ultima_movimentacao.head())
print(df2_ultima_movimentacao.shape)
# Out:
# shape: (5, 32)
# ┌────────────┬────────────┬────────────┬────────────┬───┬───────────┬──────┬───────────┬───────────┐
# │ CPF_CNPJ   ┆ NUMERO_CON ┆ ANO_MES_MO ┆ DATA_MOVIM ┆ … ┆ FLAG_RENE ┆      ┆ creditos_ ┆ creditos_ │
# │ ---        ┆ TRATO      ┆ VIMENTO    ┆ ENTO       ┆   ┆ GOCIACAO  ┆ ---  ┆ a_vencer  ┆ vencidos  │
# │ f64        ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---       ┆ str  ┆ ---       ┆ ---       │
# │            ┆ f64        ┆ str        ┆ date       ┆   ┆ str       ┆      ┆ f32       ┆ f32       │
# ╞════════════╪════════════╪════════════╪════════════╪═══╪═══════════╪══════╪═══════════╪═══════════╡
# │ 1.4243e10  ┆ 2.684952e6 ┆ 2025-08    ┆ 2025-08-31 ┆ … ┆ NAO       ┆ null ┆ 0.0       ┆ 0.0       │
# │ 8.2670e9   ┆ 247251.0   ┆ 2025-08    ┆ 2025-08-31 ┆ … ┆ SIM       ┆ null ┆ 0.0       ┆ 0.0       │
# │ 5.24458952 ┆ 3.005494e6 ┆ 2025-08    ┆ 2025-08-31 ┆ … ┆ NAO       ┆ null ┆ 0.0       ┆ 0.0       │
# ...

# %%
# Salvar em CSV
#df2_ultima_movimentacao.write_csv(f"saidacartao_{hoje}.csv",separator=";",include_header=True)
df2_ultima_movimentacao.write_parquet(f"saidacartao_{hoje}.parquet")

# %% [markdown]
# ## Atraso médio até 60 dias

# %%
# Filtro e seleção
df1_concatenado_atraso60 = df_concatenado.filter(pl.col("dias_maior_atraso") <= 60).select(
    ["cpf_cnpj", "id_contrato", "dias_maior_atraso", "data","anomes_new"]
)

df2_concatenado_atraso60 = df2_concatenado.filter(pl.col("DIAS_MAIOR_ATRASO") <= 60).select(
    ["CPF_CNPJ", "NUMERO_CONTRATO", "DIAS_MAIOR_ATRASO", "DATA_CONTRATO","DATA_MOVIMENTO"]
)

# Adiciona coluna BASE
df1_concatenado_atraso60 = df1_concatenado_atraso60.with_columns(
    pl.lit("CARNE").alias("base")
)

df2_concatenado_atraso60 = df2_concatenado_atraso60.with_columns(
    pl.lit("CARTAO").alias("BASE")
)

# Renomeia colunas para padronizar
df2_concatenado_atraso60 = df2_concatenado_atraso60.rename({
    "DATA_CONTRATO": "data",
    "NUMERO_CONTRATO": "id_contrato",
    "DATA_MOVIMENTO": "anomes_new"
})

df2_concatenado_atraso60 = df2_concatenado_atraso60.rename({
    col: col.lower() for col in df2_concatenado_atraso60.columns
})

# %%
df1_concatenado_atraso60.head(3)
# Out:
# shape: (3, 6)
# ┌────────────┬──────────────┬───────────────────┬────────────┬────────────┬───────┐
# │ cpf_cnpj   ┆ id_contrato  ┆ dias_maior_atraso ┆ data       ┆ anomes_new ┆ base  │
# │ ---        ┆ ---          ┆ ---               ┆ ---        ┆ ---        ┆ ---   │
# │ f64        ┆ f64          ┆ i32               ┆ date       ┆ date       ┆ str   │
# ╞════════════╪══════════════╪═══════════════════╪════════════╪════════════╪═══════╡
# │ 2.030098e6 ┆ 1.0769e10    ┆ 0                 ┆ 2024-02-07 ┆ 2025-05-01 ┆ CARNE │
# │ 3.64398e6  ┆ 1.2257e10    ┆ 4                 ┆ 2024-10-03 ┆ 2025-05-01 ┆ CARNE │
# │ 3.69195e6  ┆ 1.40988049e8 ┆ 4                 ┆ 2024-04-06 ┆ 2025-05-01 ┆ CARNE │
# └────────────┴──────────────┴───────────────────┴────────────┴────────────┴───────┘

# %%
df2_concatenado_atraso60.head(3)
# Out:
# shape: (3, 6)
# ┌───────────┬─────────────┬───────────────────┬────────────┬────────────┬────────┐
# │ cpf_cnpj  ┆ id_contrato ┆ dias_maior_atraso ┆ data       ┆ anomes_new ┆ base   │
# │ ---       ┆ ---         ┆ ---               ┆ ---        ┆ ---        ┆ ---    │
# │ f64       ┆ f64         ┆ i32               ┆ date       ┆ date       ┆ str    │
# ╞═══════════╪═════════════╪═══════════════════╪════════════╪════════════╪════════╡
# │ 4.3858e9  ┆ 170316.0    ┆ 5                 ┆ 2022-03-02 ┆ 2025-08-31 ┆ CARTAO │
# │ 7.3934e9  ┆ 170408.0    ┆ 29                ┆ 2022-03-02 ┆ 2025-08-31 ┆ CARTAO │
# │ 4.5394e10 ┆ 170599.0    ┆ 6                 ┆ 2022-03-02 ┆ 2025-08-31 ┆ CARTAO │
# └───────────┴─────────────┴───────────────────┴────────────┴────────────┴────────┘

# %%
df_concatenado_atraso60 = pl.concat([df1_concatenado_atraso60, df2_concatenado_atraso60], how="vertical")

# %%
#df_concatenado_atraso60.shape

# %%
#df_concatenado

# %%
#df_concatenado.filter((pl.col("cpf_cnpj")== 20486561291))

# %%
#df2_concatenado.filter((pl.col("CPF_CNPJ")== 20486561291))

# %%
'''df_media_maior_atraso = df_concatenado_atraso60.group_by("cpf_cnpj").agg(
    pl.mean("dias_maior_atraso").alias("mean_dias_maior_atraso"),
).sort("mean_dias_maior_atraso", descending=True)'''
# Out:
# 'df_media_maior_atraso = df_concatenado_atraso60.group_by("cpf_cnpj").agg(\n    pl.mean("dias_maior_atraso").alias("mean_dias_maior_atraso"),\n).sort("mean_dias_maior_atraso", descending=True)'

# %%
#df_media_maior_atraso

# %%
#df_media_maior_atraso.write_csv(f"media_maior_atraso_{hoje}.csv",separator=";",include_header=True)
df_concatenado_atraso60.write_parquet(f"df_maior_atraso_ate_60_{hoje}.parquet")

# %%
#df_media_maior_atraso.filter(pl.col("cpf_cnpj")== 70237786915) # filtro

# %%
#df_media_maior_atraso.sample(10)
